# %% [raw]
# 1. Bold Syntax (using **)

# %% [markdown]
# **Sakshi**

# %% [raw]
# 2. Italic Syntax(using *)

# %% [markdown]
# *HELLO*

# %% [raw]
# 3.Heading Syntax(using hash'#')

# %% [markdown]
# # WELCOME
# ## TO
# ### SEE
# # My Task 1

# %% [raw]
# 4.Highlight(using mark)

# %% [markdown]
# My Name is <mark>Sakshi Barai<mark>.

# %% [raw]
# 5.Subscript(using sub)

# %% [markdown]
# A<sub>B</sub>C<sub>D</sub>E

# %% [raw]
# 6.Superscript (using sup)

# %% [markdown]
# A<sup>B</sup>C<sup>D</sup>E

# %% [raw]
# 7.To cut out mistake (using ~~)

# %% [markdown]
# ~~Saashi~~ Sakshi

# %% [raw]
# 8.Ordered List(ol)

# %% [markdown]
# <ol><li>This is first</li><li>This is Second</li></ol>

# %% [raw]
# 9.Unordered List(ul)

# %% [markdown]
# <ul><li>Teachers</li><li>Students</li></ul>

# %% [raw]
# 10.Comments

# %% [markdown]
# <! --this is comment
# abcde -->

# %% [raw]
# 11.Inserting links

# %% [markdown]
# [LINK_Of_Amazon](https://www.amazon.in/?tag=googmantxtmob170-21&ascsubtag=_k_Cj0KCQjwjNS3BhChARIsAOxBM6rJsU0h1AZVrDM8vWV7HryleLQEwM0lsqMve29t5TKzkB1-poR5amAaAt5-EALw_wcB_k_)

# %% [raw]
# 12.Inserting Images

# %% [markdown]
# [Image](![Screenshot 2024-09-26 193000.png](attachment:4b284b81-e37f-4fb7-8831-2d11acd8aca7.png))
# [image](https://artincontext.org/web-stories/peacock-drawing/)

# %% [raw]
# 13.Backgroud colour

# %% [markdown]
# <code Style="background:red">Hello</Code>

# %% [raw]
# 14.Code

# %% [markdown]
# <code>print('hiii')</code>

# %% [raw]
# 15.Horizontal lines

# %% [markdown]
# ***
# ---

# %% [raw]
# 16.Url and Links

# %% [markdown]
# <https://www.youtube.com/>
