# %% [markdown]
# # 1. Bold Syntax (using **)

# %% [markdown]
# **Sakshi**

# %% [markdown]
# # 2. Italic Syntax(using *)

# %% [markdown]
# *HELLO*

# %% [markdown]
#  # 3.Heading Syntax(using hash'#')

# %% [markdown]
# ---
# # WELCOME
# ## TO
# ### SEE
# # My Task 1
# ---

# %% [markdown]
# # 4.Highlight(using mark)

# %% [markdown]
# My Name is <mark>Sakshi Barai<mark>.

# %% [markdown]
# # 5.Subscript(using sub)

# %% [markdown]
# A<sub>B</sub>C<sub>D</sub>E

# %% [markdown]
# # 6.Superscript (using sup)

# %% [markdown]
# A<sup>B</sup>C<sup>D</sup>E

# %% [markdown]
# # 7.To cut out mistake (using ~~)

# %% [markdown]
# ~~Saashi~~ Sakshi

# %% [markdown]
# # 8.Tables

# %% [markdown]
# *FRUIT TABLE*
# ***
# |Fruit name|Fruit Colour|Fruit Price Per item|
# |-----|-----|-----|
# |Mango|Yellow|30 Rupees|
# |Apple|Red|50 rupees|

# %% [markdown]
# # 9.Ordered List(ol)

# %% [markdown]
# <ol><li>This is first</li><li>This is Second</li></ol>

# %% [markdown]
# # 10.Unordered List(ul)

# %% [markdown]
# <ul><li>Teachers</li><li>Students</li></ul>

# %% [markdown]
# # 11.Comments(using <!.....>)

# %% [markdown]
# "<!--this is comment
# abcde --> "  -->Here is comment

# %% [markdown]
# # 12.Inserting links

# %% [markdown]
# [LINK_Of_Amazon](https://www.amazon.in/?tag=googmantxtmob170-21&ascsubtag=_k_Cj0KCQjwjNS3BhChARIsAOxBM6rJsU0h1AZVrDM8vWV7HryleLQEwM0lsqMve29t5TKzkB1-poR5amAaAt5-EALw_wcB_k_)

# %% [markdown]
# # 13.Inserting Images

# %% [markdown]
# (![Screenshot 2024-09-26 193000.png](attachment:4b284b81-e37f-4fb7-8831-2d11acd8aca7.png))
#
# ***
# [DUBAI IMAGE](https://wallpapercave.com/wp/wp1851485.jpg)

# %% [markdown]
# # 14.Backgroud colour

# %% [markdown]
# <code Style="background:purple"><font style="color:yellow">Have a Good Day</font></Code>

# %% [markdown]
# # 15.Font Colour

# %% [markdown]
# <font style="color:red"> **Sakshi**</font>

# %% [markdown]
# # 16.Font Size and Underline

# %% [markdown]
# <font size="6"><u>Sakshi</u></font>

# %% [markdown]
# # 17.GIFS

# %% [markdown]
# (![12537.gif](attachment:7c73f707-4194-4e6c-b226-74179841499d.gif))

# %% [markdown]
# # 18.Horizontal lines

# %% [markdown]
# ***
# ***
#
# ---
#
# ---
# ***

# %% [markdown]
# # 19.Url and Links

# %% [markdown]
# [CLICK HERE TO WATCH YOUTUBE](<https://www.youtube.com/>)
#
# ***
#
# [EMAIL](abcde@gmail.com)

# %% [markdown]
# # 20.Inserting Videos

# %% [markdown]
# [STANDUP COMEDY](https://www.youtube.com/watch?v=FhCbx2TmFUE)
